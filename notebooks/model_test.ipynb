# %%
import inspect
from braindecode.models import Deep4Net

print(inspect.signature(Deep4Net.__init__))
# Out:
# (self, n_chans=None, n_outputs=None, n_times=None, final_conv_length='auto', n_filters_time=25, n_filters_spat=25, filter_time_length=10, pool_time_length=3, pool_time_stride=3, n_filters_2=50, filter_length_2=10, n_filters_3=100, filter_length_3=10, n_filters_4=200, filter_length_4=10, activation_first_conv_nonlin: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.activation.ELU'>, first_pool_mode='max', first_pool_nonlin: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.linear.Identity'>, activation_later_conv_nonlin: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.activation.ELU'>, later_pool_mode='max', later_pool_nonlin: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.linear.Identity'>, drop_prob=0.5, split_first_layer=True, batch_norm=True, batch_norm_alpha=0.1, stride_before_pool=False, chs_info=None, input_window_seconds=None, sfreq=None)

# %%
import inspect
from braindecode.models import Deep4Net

sig = inspect.signature(Deep4Net.__init__)

for name, param in sig.parameters.items():
    if name == "self":
        continue
    print(f"{name}: default={param.default}")
# Out:
# n_chans: default=None
# n_outputs: default=None
# n_times: default=None
# final_conv_length: default=auto
# n_filters_time: default=25
# n_filters_spat: default=25
# filter_time_length: default=10
# pool_time_length: default=3
# pool_time_stride: default=3
# n_filters_2: default=50
# filter_length_2: default=10
# n_filters_3: default=100
# filter_length_3: default=10
# n_filters_4: default=200
# filter_length_4: default=10
# activation_first_conv_nonlin: default=<class 'torch.nn.modules.activation.ELU'>
# first_pool_mode: default=max
# first_pool_nonlin: default=<class 'torch.nn.modules.linear.Identity'>
# activation_later_conv_nonlin: default=<class 'torch.nn.modules.activation.ELU'>
# later_pool_mode: default=max
# later_pool_nonlin: default=<class 'torch.nn.modules.linear.Identity'>
# drop_prob: default=0.5
# split_first_layer: default=True
# batch_norm: default=True
# batch_norm_alpha: default=0.1
# stride_before_pool: default=False
# chs_info: default=None
# input_window_seconds: default=None
# sfreq: default=None
